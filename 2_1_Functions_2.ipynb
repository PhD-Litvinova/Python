# %% [markdown]
# # Домашнє завдання до теми "Functions"

# %% [markdown]
# 1. Напишіть фукнцію `print_message`, яка виводить на екран "Я програмую на Python💪" і викличіть цю фукнцію 5 разів (найкраще це зробити в циклі).
#
#   **Увага**: фукнція має робити чітко лише зазначений функціонал. Наявність додаткового функціоналу і аргументів, які не потрібні для виконання безпосередньо завдання, буде вважатись помилкою.

# %%
def print_message():
    print('Я програмую на Python💪')
for a in  range(5):
    print_message()
# Out:
# Я програмую на Python💪
# Я програмую на Python💪
# Я програмую на Python💪
# Я програмую на Python💪
# Я програмую на Python💪

# %% [markdown]
# 2. Напишіть функцію `calculation` яка приймає на вхід 4 аргументи типу int - `a`, `b`, `c`, `d` і вертає результат обчислення такої формули: $ (a + b - c) * d $.
#
#   Викличте функцію на наступному наборі аргументів і виведіть результат на екран:
#   ```
#   a = 16
#   b = 4
#   c = 9
#   d = 3
#   ```

# %%
def calculation(a, b, c, d):
   return (a + b - c) * d

a = 16
b = 4
c = 9
d = 3
result = calculation(a, b, c, d)
print(f'результат обчислень = {result}')
# Out:
# результат обчислень = 33

# %% [markdown]
# 3. Напишіть функцію, яка додає до аргумента 15 і вертає результат додавання. Викличте функцію, передаючи в якості аргументів кожну з наступних змінних по черзі, і виведіть кожного разу результат на екран.
# ```
# x = 9
# y = 14
# z = -19
# ```

# %%
def add_15(x,y,z):
  return x + 15, y + 15, z + 15

x = 9
y = 14
z = -19


print(add_15(x,y,z))
# Out:
# (24, 29, -4)

# %%
def add_15(arg):
    return arg + 15

x = 9
y = 14
z = -19

result_x = add_15(x)
result_y = add_15(y)
result_z = add_15(z)

print(result_x, result_y, result_z)
# Out:
# 24 29 -4

# %%
def add_15(arg):
  return arg + 15

arg = (9, 14, -19)

for a in arg:
    print(add_15(a))
# Out:
# 24
# 29
# -4

# %%
def add_15(arg):
    return arg + 15

arg = (9, 14, -19)
results = [add_15(a) for a in arg]

print(results)
# Out:
# [24, 29, -4]

# %% [markdown]
# 4. Напишіть функцію `multipy_numbers`, яка приймає два числа як аргументи і повертає їх добуток.
#
#   Викличіть функцію `multipy_numbers` на парах чисел
# - 10 і 2
# - 7 і 8
# - 1024 і 999.
#
#   Виведіть результат кожного виклику.
#   При виконанні цього завдання з використанням циклу - отримаєте 2х балів за нього :)

# %%
def multipy_numbers(x,y):
  return x * y

num = {10:2, 7:8, 1024:999}
for key, value in num.items():
    result = multipy_numbers(key, value)
    print(result)
# Out:
# 20
# 56
# 1022976

# %%
def add_multipy_numbers(x,y):
    return x * y

num_par = [(10,2), (7,8), (1024,999)]

for x, y in num_par:
    result = multipy_numbers(x, y)

    print(result)
# Out:
# 20
# 56
# 1022976

# %%
def add_multipy_numbers(x,y):
    return x * y

f = (10,2)
d = (7,8)
g = (1024,999)

result_1 = multipy_numbers(*f)
result_2 = multipy_numbers(*d)
result_3 = multipy_numbers(*g)

print(result_1, result_2,result_3)
# Out:
# 20 56 1022976

# %%
def multipy_numbers(x, y):
    return x * y

num_par = [(10, 2), (7, 8), (1024, 999)]

result_1 = multipy_numbers(*num_par[0])
result_2 = multipy_numbers(*num_par[1])
result_3 = multipy_numbers(*num_par[2])

print(result_1, result_2, result_3)
# Out:
# 20 56 1022976

# %%
def multipy_numbers(x,y):
  return x * y

num_par = [(10,2), (7,8), (1024,999)]

result = [multipy_numbers(*a) for a in num_par]

print(result)
# Out:
# [20, 56, 1022976]

# %% [markdown]
# 5. **Ділення з перевіркою типів.**
#
#   1. Напишіть функцію `int_division` яка приймає на вхід два аргументи типу `int` - `a` і `b`, і виконує ділення першого аргумента на другий: `a/b`. При цьому функція перед діленням перевіряє, чи другий аргумент не дорівнює 0. Якщо другий аргумент не 0, фукнція вертає результат ділення, інакше - замість виконання ділення, вертає повідомлення на екран "Не можу виконати ділення на 0".
#
#     Якщо типи, надані у функцію, не `int` - функція виводить повідомлення "Не працюю з такими типами даних.".
#
#   2. Запустіть функцію на наступних парах чисел:
# - 12 і 6
# - 20 і 0
# - 112 і 10
# - 99 і 0
# - 11 i 1.1
#
#     і виведіть на екран повідомлення "Результат роботи функції: " - і далі те, що повернула функція.
#
#   3. Дайте відповідь на питання: "Чому в деяких випадках функція повернула None?"

# %%
def int_division(a:int, b:int) ->int:
  if type(a) != int or type(b) != int:
    return 'Не працюю з такими типами даних'
  if b == 0:
     return 'Не можу виконати ділення на 0'
  else:
    return a / b

num_par = [(12,6), (20,0), (112,10), (99,0), (11,1.1)]
result = [ int_division(*i) for i in num_par]

print(f'Результат роботи функції: {result}')
# Out:
# Результат роботи функції: [2.0, 'Не можу виконати ділення на 0', 11.2, 'Не можу виконати ділення на 0', 'Не працюю з такими типами даних']

# %%
def int_division(a:int, b:int) ->int:
  if type(a) != int or type(b) != int:
    print ('Не працюю з такими типами даних')
  if b == 0:
     print('Не можу виконати ділення на 0')
  else:
     return a / b

num_par = [(12,6), (20,0), (112,10), (99,0), (11,1.1)]
result = [ int_division(*i) for i in num_par]

print(f'Результат роботи функції: {result}')
# Out:
# Не можу виконати ділення на 0
# Не можу виконати ділення на 0
# Не працюю з такими типами даних
# Результат роботи функції: [2.0, None, 11.2, None, 10.0]

# %% [markdown]
# "Чому в деяких випадках функція повернула None?". Воно трапляється, коли ми в функції не пишемо return, а лише print('повідомлення про...'). Тобто, коли викликаємо таку функцію, результатом буде None, оскільки Python автоматично повертає None, якщо немає явного return. Щоб уникнути None і отримати повідомлення як результат роботи функції, треба використовувати return, а не просто print.
